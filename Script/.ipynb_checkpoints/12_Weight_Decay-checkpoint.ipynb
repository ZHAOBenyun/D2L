# %%
# %matplotlib inline
import torch
from torch import nn
from d2l import torch as d2l

# %% [markdown]
# ### Weight Decay Step by Step

# %% [markdown]
# ##### Weight Decay (L2 Regularization) is the Most Common Way to Regularize
#
# (**$$y = 0.05 + \sum_{i = 1}^d 0.01 x_i + \epsilon \text{ where }
# \epsilon \sim \mathcal{N}(0, 0.01^2).$$**)
#
# We choose our label to be a linear function of our inputs,
# corrupted by Gaussian noise with zero mean and standard deviation 0.01.
# To make the effects of overfitting pronounced,
# we can increase the dimensionality of our problem to $d = 200$
# and work with a small training set containing only 20 examples.

# %%
n_train, n_test, num_inputs, batch_size = 20, 100, 200, 5
true_w = torch.ones((num_inputs, 1)) * 0.01  # true_w.shape = (200, 1) all are ones
true_b = 0.05


train_data = d2l.synthetic_data(true_w, true_b, n_train)
train_iter = d2l.load_array(train_data, batch_size)

test_data = d2l.synthetic_data(true_w, true_b, n_test)
test_iter = d2l.load_array(test_data, batch_size, is_train=False)

# %% [markdown]
# #### Initilize parameters

# %%
def init_params():
    w = torch.normal(0, 1, size=(num_inputs, 1), requires_grad=True)
    b = torch.zeros(1, requires_grad=True)
    return [w, b]

# %% [markdown]
# #### L2 penalty

# %%
def l2_penalty(w):
    return torch.sum(w.pow(2)) / 2  # (w^2)/2

# %% [markdown]
# #### Define the Training Loop

# %%
def train(lambd):
    w, b = init_params()
    net = lambda X: d2l.linreg(X, w, b)  
    # lambda variable : expression = net(X) can directly run the expression
    loss = d2l.squared_loss
    num_epochs, lr = 100, 0.003
    animator = d2l.Animator(xlabel='epochs', ylabel='loss', yscale='log',
                            xlim=[5, num_epochs], legend=['train', 'test']) 
    for epoch in range(num_epochs):
        for X, y in train_iter:
            # with torch.enable_grad():
            l = loss(net(X), y) + lambd * l2_penalty(w)  # loss function with l2 penalty
            l.sum().backward()                           # back prop
            d2l.sgd([w, b], lr, batch_size)              # optimizer
            if (epoch + 1) % 5 == 0:                    # get the remainder of division
                animator.add(epoch + 1, (d2l.evaluate_loss(net, train_iter, loss),
                                         d2l.evaluate_loss(net, test_iter, loss)))
    print('L2 norm of w:', torch.norm(w).item())

# %%
train(lambd = 0)  # lambda = 0 means no L2 norm
# Out:
# L2 norm of w: 13.543148040771484

# %%
train(lambd = 3)
# Out:
# L2 norm of w: 0.3590722382068634

# %% [markdown]
# ### Weight Decay easily by PyTorch

# %%
def train_concise(wd):
    net = nn.Sequential(nn.Linear(num_inputs, 1))
    for param in net.parameters():
        param.data.normal_()
    loss = nn.MSELoss()
    num_epochs, lr = 100, 0.003
    trainer = torch.optim.SGD([{'params': net[0].weight, 'weight_decay': wd}, {'params': net[0].bias}], lr=lr)  
    # 'weight_decay' = lambda
    # weight decay can be set in the optimizer in PyTorch; TensorFlow; MXNet while not in the loss function
    animator = d2l.Animator(xlabel='epochs', ylabel='loss', yscale='log',
                            xlim=[5, num_epochs], legend=['train', 'test'])
    for epoch in range(num_epochs):
        for X, y in train_iter:
            with torch.enable_grad():
                trainer.zero_grad()
                l = loss(net(X), y)
            l.backward()                   # back prop
            trainer.step()                 # update optimizer
            if (epoch + 1) % 5 == 0:       # get the remainder of division
                animator.add(epoch + 1, (d2l.evaluate_loss(net, train_iter, loss),
                                         d2l.evaluate_loss(net, test_iter, loss)))
    print('L2 norm of w:',  net[0].weight.norm().item())

# %%
train_concise(0)
# Out:
# L2 norm of w: 12.17867374420166

# %%
train_concise(3)
# Out:
# L2 norm of w: 0.47167089581489563
